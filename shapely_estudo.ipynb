# %% [markdown]
# <a href="https://colab.research.google.com/github/gaeldesenvolvedorgis-coder/shapely_estudos/blob/main/shapely_estudo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from shapely.geometry import Polygon, LineString, Point
import geopandas as gpd

# %%
patch.area
# Out:
# 313.6548490545941

# %%
p5 = Point(85,30)
p6 = Point(80,25)
l1 = LineString([p5,p6])
poly1 = Polygon([(82,25),(83,26),(82,23)])
poly1
# Out:
# <POLYGON ((82 25, 83 26, 82 23, 82 25))>

# %%
geoseries_shapely = gpd.GeoSeries([p5,p6])
df_shapely = gpd.GeoDataFrame(geometry=geoseries_shapely, crs='EPSG:4326')
df_shapely.columns = ['geometry']
df_shapely
# Out:
#         geometry
# 0  POINT (85 30)
# 1  POINT (80 25)

# %%
df_shapely.plot()
# Out:
# <Axes: >

# %%
df_shapely.to_file(r'.shp')
